# %%
# Import the library to mount Google Drive
from google.colab import drive
# Mount the Google Drive at /content/drive
drive.mount('/content/drive/', force_remount = True)
# Out:
# Mounted at /content/drive/

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip  /content/drive/MyDrive/scan_trad_data.zip -d /content/drive/MyDrive/data
# Out:
# Archive:  /content/drive/MyDrive/scan_trad_data.zip
# replace /content/drive/MyDrive/data/README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Import the yoloV12 model
from ultralytics import YOLO

yolo = YOLO('yolo12n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.34M/5.34M [00:00<00:00, 76.8MB/s]

# %%
results = yolo.train(data='/content/drive/MyDrive/data/data.yaml', epochs = 100,imgsz = 640, patience = 10 , save = True )
# Out:
# Ultralytics 8.3.150 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
image = ['test_scan1.jpg', '/content/image1.webp']
results = yolo(image, conf=0.5,iou = 0.5)

for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 640x640 7 text_bubbles, 13.6ms
# 1: 640x640 13 text_bubbles, 13.6ms
# Speed: 4.0ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=666x1100>
# <PIL.Image.Image image mode=RGB size=714x1024>

# %%
from ultralytics import YOLO
yolo = YOLO ('best.pt')

# %%
metrics= yolo.val(data ="/content/drive/MyDrive/data/data.yaml",imgsz=640, conf=0.3, iou=0.5)
# Out:
# Ultralytics 8.3.150 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 35.5±7.6 MB/s, size: 74.4 KB)
# val: Scanning /content/drive/MyDrive/data/valid/labels.cache... 1002 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1002/1002 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 63/63 [00:16<00:00,  3.84it/s]
#                    all       1002       6624      0.899      0.882      0.913      0.696
#            text_bubble        995       6246      0.988      0.973      0.987      0.839
#              text_free        135        378       0.81      0.791      0.839      0.553
# Speed: 1.2ms preprocess, 5.7ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val6

# %%
metrics= yolo.val(data ="/content/drive/MyDrive/data/data.yaml",imgsz=640, conf=0.5, iou=0.5)
# Out:
# Ultralytics 8.3.150 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 41.6±8.3 MB/s, size: 80.8 KB)
# val: Scanning /content/drive/MyDrive/data/valid/labels.cache... 1002 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1002/1002 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 63/63 [00:16<00:00,  3.91it/s]
#                    all       1002       6624      0.922      0.837      0.891      0.689
#            text_bubble        995       6246       0.99      0.966      0.982      0.836
#              text_free        135        378      0.854      0.709      0.801      0.541
# Speed: 1.4ms preprocess, 5.8ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val7

# %%
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# array([    0.83638,     0.54092])

# %%
image = ['/content/download.jpg']
results = yolo(image, conf=0.05,iou = 0.5)

for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 320x640 (no detections), 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=318x159>
